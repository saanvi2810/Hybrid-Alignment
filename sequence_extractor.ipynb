# %%
import requests
import time

INPUT_FILE = "/Users/saanviaima/Documents/GitHub/Hyrbid-Alignment/HMM-iter1-scores-table.txt"
OUTPUT_FASTA = "all_sequences.fasta"
NOT_FOUND_LOG = "not_found.txt"
ORGANISM_ID = 9606  #human
PAUSE_BETWEEN_REQUESTS = 0.3  

def extract_gene_names(file_path):
    def extract_middle_from_name(name):
        parts = name.split('_')
        if len(parts) >= 3:
            return parts[1]  
        elif len(parts) == 2:
            return parts[1] 
        return None

    gene_names = []
    with open(file_path, 'r') as file:
        for line in file:
            if line.strip():
                name = line.split()[0]
                gene = extract_middle_from_name(name)
                if gene:
                    gene_names.append(gene)
    return list(set(gene_names)) 


def get_uniprot_accession(gene_name):
    url = (
        f"https://rest.uniprot.org/uniprotkb/search?"
        f"query=gene:{gene_name}+AND+organism_id:{ORGANISM_ID}+AND+reviewed:true"
        f"&fields=accession&format=tsv"
    )
    r = requests.get(url)
    if r.status_code == 200:
        lines = r.text.strip().split('\n')
        if len(lines) > 1:
            return lines[1].split('\t')[0]  
    return None

def download_fasta(accession):
    url = f"https://rest.uniprot.org/uniprotkb/{accession}.fasta"
    r = requests.get(url)
    if r.status_code == 200:
        return r.text
    return None


gene_names = extract_gene_names(INPUT_FILE)
print(f"Found {len(gene_names)} unique gene names.")

with open(OUTPUT_FASTA, 'w') as fasta_out, open(NOT_FOUND_LOG, 'w') as log_out:
    for gene in gene_names:
        print(f"Fetching {gene}...", end='')
        accession = get_uniprot_accession(gene)
        if accession:
            sequence = download_fasta(accession)
            if sequence:
                fasta_out.write(sequence)
                print(f" ✓ ({accession})")
            else:
                print(" ✗ (FASTA not found)")
                log_out.write(f"{gene}\t{accession}\tFASTA not found\n")
        else:
            print(" ✗ (No accession)")
            log_out.write(f"{gene}\tNOT FOUND\n")
        time.sleep(PAUSE_BETWEEN_REQUESTS)
# Out:
# Found 484 unique gene names.
# Fetching MARK2... ✓ (Q7KZI7)
# Fetching GRK2... ✓ (P25098)
# Fetching STK32B... ✓ (Q9NY57)
# Fetching DCLK3... ✓ (Q9C098)
# Fetching AKT1... ✓ (P31749)
# Fetching SIK1B... ✗ (No accession)
# Fetching MAPK11... ✓ (Q15759)
# Fetching LIMK1... ✓ (P53667)
# Fetching CSNK1G2... ✓ (P78368)
# Fetching ARAF... ✓ (P10398)
# Fetching LRRK1... ✓ (Q38SD2)
# Fetching HUNK... ✓ (P57058)
# Fetching PIM3... ✓ (Q86V86)
# Fetching SPEG... ✓ (Q15772)
# Fetching EPHB6... ✓ (O15197)
# Fetching NTRK3... ✓ (Q16288)
# Fetching SRPK1... ✓ (Q96SB4)
# Fetching INSRR... ✓ (P14616)
# Fetching ILK... ✓ (Q13418)
# Fetching ALK... ✓ (Q9UM73)
# Fetching EPHB3... ✓ (P54753)
# Fetching STKLD1... ✓ (Q8NE28)
# Fetching TTBK2... ✓ (Q6IQ55)
# Fetching STK38... ✓ (Q15208)
# Fetching RIPK3... ✓ (Q9Y572)
# Fetching RSKR... ✓ (Q96LW2)
# Fetching PKDCC... ✓ (Q504Y2)
# Fetching SGK1... ✓ (O00141)
# Fetching DAPK2... ✓ (Q9UIK4)
# Fetching FGR... ✓ (P09769)
# Fetching BMPR1B... ✓ (O00238)
# Fetching TRIO... ✓ (O75962)
# Fetching MAP3K10... ✓ (Q02779)
# Fetching SRC... ✓ (P12931)
# Fetching MAP4K3... ✓ (Q8IVH8)
# Fetching MAP3K20... ✓ (Q9NYL2)
# Fetching CAMK2B... ✓ (Q13554)
# Fetching CAMK1G... ✓ (Q96NX5)
# Fetching TSSK3... ✓ (Q96PN8)
# Fetching STK40... ✓ (Q8N2I9)
# Fetching LIMK2... ✓ (P53671)
# Fetching EPHA2... ✓ (P29317)
# Fetching CDKL5... ✓ (O76039)
# Fetching TGFBR1... ✓ (P36897)
# Fetching GUCY2F... ✓ (P51841)
# Fetching DDR1... ✓ (Q08345)
# Fetching PRKD2... ✓ (Q9BZL6)
# Fetching CAMK2A... ✓ (Q9UQM7)
# Fetching PDPK1... ✓ (O15530)
# Fetching TRIB1... ✓ (Q96RU8)
# Fetching CDKL3... ✓ (Q8IVW4)
# Fetching PRKAA2... ✓ (P54646)
# Fetching STK16... ✓ (O75716)
# Fetching STK17A... ✓ (Q9UEE5)
# Fetching LATS1... ✓ (O95835)
# Fetching GUCY2C... ✓ (P25092)
# Fetching NEK9... ✓ (Q8TD19)
# Fetching PRKD1... ✓ (Q15139)
# Fetching TP53RK... ✓ (Q96S44)
# Fetching MAPK8... ✓ (P45983)
# Fetching MKNK1... ✓ (Q9BUB5)
# Fetching FRK... ✓ (P42685)
# Fetching MAPK10... ✓ (P53779)
# Fetching STK32C... ✓ (Q86UX6)
# Fetching DYRK4... ✓ (Q9NR20)
# Fetching ACVR1B... ✓ (P36896)
# Fetching MYO3A... ✓ (Q8NEV4)
# Fetching VRK1... ✓ (Q99986)
# Fetching CDK8... ✓ (P49336)
# Fetching HASPIN... ✓ (Q8TF76)
# Fetching CDC7... ✓ (O00311)
# Fetching RIPK1... ✓ (Q13546)
# Fetching ACVR2A... ✓ (P27037)
# Fetching GRK3... ✓ (P35626)
# Fetching CSNK2A3... ✓ (Q8NEV1)
# Fetching MET... ✓ (P08581)
# Fetching STK4... ✓ (Q13043)
# Fetching PAK2... ✓ (Q13177)
# Fetching STK38L... ✓ (Q9Y2H1)
# Fetching CDK2... ✓ (P24941)
# Fetching CDK14... ✓ (O94921)
# Fetching DCLK2... ✓ (Q8N568)
# Fetching STK35... ✓ (Q8TDR2)
# Fetching NEK1... ✓ (Q96PY6)
# Fetching UHMK1... ✓ (Q8TAS1)
# Fetching TBK1... ✓ (Q9UHD2)
# Fetching GRK1... ✓ (Q15835)
# Fetching PIM1... ✓ (P11309)
# Fetching CHUK... ✓ (O15111)
# Fetching PIM2... ✓ (Q9P1W9)
# Fetching MAP3K14... ✓ (Q99558)
# Fetching NRK... ✓ (Q7Z2Y5)
# Fetching PTK7... ✓ (Q13308)
# Fetching PLK4... ✓ (O00444)
# Fetching NEK8... ✓ (Q86SG6)
# Fetching MAP4K4... ✓ (O95819)
# Fetching PRKCA... ✓ (P17252)
# Fetching MINK1... ✓ (Q8N4C8)
# Fetching WEE2... ✓ (P0C1S8)
# Fetching PDGFRA... ✓ (P16234)
# Fetching TSSK2... ✓ (Q96PF2)
# Fetching MELK... ✓ (Q14680)
# Fetching FYN... ✓ (P06241)
# Fetching MAP4K1... ✓ (Q92918)
# Fetching RAF1... ✓ (P04049)
# Fetching DSTYK... ✓ (Q6XUX3)
# Fetching SCYL3... ✓ (Q8IZE3)
# Fetching IGF1R... ✓ (P08069)
# Fetching HIPK3... ✓ (Q9H422)
# Fetching MAP3K15... ✓ (Q6ZN16)
# Fetching LYN... ✓ (P07948)
# Fetching MAP2K6... ✓ (P52564)
# Fetching DAPK1... ✓ (P53355)
# Fetching ANKK1... ✓ (Q8NFD2)
# Fetching DCLK1... ✓ (O15075)
# Fetching MAP2K2... ✓ (P36507)
# Fetching SRMS... ✓ (Q9H3Y6)
# Fetching PRKCD... ✓ (Q05655)
# Fetching STK24... ✓ (Q9Y6E0)
# Fetching PLK5... ✓ (Q496M5)
# Fetching CAMK4... ✓ (Q16566)
# Fetching MAPK15... ✓ (Q8TD08)
# Fetching TLK1... ✓ (Q9UKI8)
# Fetching ULK2... ✓ (Q8IYT8)
# Fetching TLK2... ✓ (Q86UE8)
# Fetching PAK4... ✓ (O96013)
# Fetching ERBB3... ✓ (P21860)
# Fetching TEX14... ✓ (Q8IWB6)
# Fetching PRKCB... ✓ (P05771)
# Fetching STK31... ✓ (Q9BXU1)
# Fetching TSSK1B... ✓ (Q9BXA7)
# Fetching RPS6KA6... ✓ (Q9UK32)
# Fetching CDK17... ✓ (Q00537)
# Fetching TGFBR2... ✓ (P37173)
# Fetching RYK... ✓ (P34925)
# Fetching PDPK2P... ✓ (Q6A1A2)
# Fetching LATS2... ✓ (Q9NRM7)
# Fetching CAMKK2... ✓ (Q96RR4)
# Fetching MAPK12... ✓ (P53778)
# Fetching CSK... ✓ (P41240)
# Fetching EPHA5... ✓ (P54756)
# Fetching AURKB... ✓ (Q96GD4)
# Fetching MARK3... ✓ (P27448)
# Fetching MAST4... ✓ (O15021)
# Fetching PRKACA... ✓ (P17612)
# Fetching WNK2... ✓ (Q9Y3S1)
# Fetching BTK... ✓ (Q06187)
# Fetching NEK2... ✓ (P51955)
# Fetching ULK1... ✓ (O75385)
# Fetching NLK... ✓ (Q9UBE8)
# Fetching CSNK1A1... ✓ (P48729)
# Fetching TRIB2... ✓ (Q92519)
# Fetching BMP2K... ✓ (Q9NSY1)
# Fetching MATK... ✓ (P42679)
# Fetching ABL2... ✓ (P42684)
# Fetching AAK1... ✓ (Q2M2I8)
